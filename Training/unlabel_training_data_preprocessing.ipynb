# %%
rom google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/Major_Project/Codebase/training/unlabeled_training_reddit.csv'

# %%
import pandas as pd
train2 = pd.read_csv(file_path)
df = pd.DataFrame(train2)
df
# Out:
#            id subreddit          author  \
# 0      bz796p   AskDocs     Scrambles99
# 1      m7mwkd   AskDocs       KingCeryn
# 2      2mh45q   AskDocs  Mordor_or_bust
# 3      2fq5mh   AskDocs         yeast-1
# 4      8ihond   AskDocs        Derek800
# ...       ...       ...             ...
# 99995  gewohl   AskDocs        BlueTipi
# 99996  blnbah   AskDocs  plywooddrywall
# 99997  ndql1u   AskDocs   1g0tquestions
# 99998  tearhc   AskDocs      Hannah2482
# 99999  qukw0e   AskDocs    TheBlank_One
#
#                                                    title  \
# 0                                      Intestinal Issues
# 1      Neck muscle flexing, possibly Omohyoid, anytim...
# 2               29/F Brown urine &amp; flu-like symptoms
# 3           Question about anti-fungal creams or lotions
# 4                            Elevated Lipase and Amylase
# ...                                                  ...
# 99995                           Why can't I eat quietly?
# ...

# %%
df = df.drop(columns=["subreddit", "timestamp"])
df
# Out:
#            id          author  \
# 0      bz796p     Scrambles99
# 1      m7mwkd       KingCeryn
# 2      2mh45q  Mordor_or_bust
# 3      2fq5mh         yeast-1
# 4      8ihond        Derek800
# ...       ...             ...
# 99995  gewohl        BlueTipi
# 99996  blnbah  plywooddrywall
# 99997  ndql1u   1g0tquestions
# 99998  tearhc      Hannah2482
# 99999  qukw0e    TheBlank_One
#
#                                                    title  \
# 0                                      Intestinal Issues
# 1      Neck muscle flexing, possibly Omohyoid, anytim...
# 2               29/F Brown urine &amp; flu-like symptoms
# 3           Question about anti-fungal creams or lotions
# 4                            Elevated Lipase and Amylase
# ...                                                  ...
# 99995                           Why can't I eat quietly?
# 99996    Red/Purple blotches on pubic area won't go away
# 99997    Are high testosterone and estrogen a good sign?
# ...

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

def preprocess_text_with_stop_words(text):
    # Lowercasing: Convert text to lowercase
    text = text.lower()

    # Remove usernames
    text = re.sub(r'@(\w+)', '', text)

    # Tokenization: Split the text into words
    words = nltk.word_tokenize(text)

    # Remove punctuation and non-alphanumeric characters
    words = [word for word in words if re.match(r'^[a-z0-9]+$', word)]

    # Remove English stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Join the words back into a single string
    preprocessed_text = ' '.join(words)

    return preprocessed_text

def preprocess_text_without_stop_words(text):
    # Lowercasing: Convert text to lowercase
    text = text.lower()

    # Remove usernames
    text = re.sub(r'@(\w+)', '', text)

    # Tokenization: Split the text into words
    words = nltk.word_tokenize(text)

    # Remove punctuation and non-alphanumeric characters
    words = [word for word in words if re.match(r'^[a-z0-9]+$', word)]

    # Join the words back into a single string
    preprocessed_text = ' '.join(words)

    return preprocessed_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
df['cleaned_text_1'] = df['text'].apply(preprocess_text_with_stop_words)
df['cleaned_text_2'] = df['text'].apply(preprocess_text_without_stop_words)

# %%
df
# Out:
#            id          author  \
# 0      bz796p     Scrambles99
# 1      m7mwkd       KingCeryn
# 2      2mh45q  Mordor_or_bust
# 3      2fq5mh         yeast-1
# 4      8ihond        Derek800
# ...       ...             ...
# 99995  gewohl        BlueTipi
# 99996  blnbah  plywooddrywall
# 99997  ndql1u   1g0tquestions
# 99998  tearhc      Hannah2482
# 99999  qukw0e    TheBlank_One
#
#                                                    title  \
# 0                                      Intestinal Issues
# 1      Neck muscle flexing, possibly Omohyoid, anytim...
# 2               29/F Brown urine &amp; flu-like symptoms
# 3           Question about anti-fungal creams or lotions
# 4                            Elevated Lipase and Amylase
# ...                                                  ...
# 99995                           Why can't I eat quietly?
# 99996    Red/Purple blotches on pubic area won't go away
# 99997    Are high testosterone and estrogen a good sign?
# ...

# %%
df.to_csv("/content/drive/MyDrive/Major_Project/Codebase/training/unlabeled_preprocessed_training.csv", index=False)
